# %% [markdown]
# # Exploratory Data Analysis
# ## Timber Supply for the Spanish Naval Industry

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df = pd.read_csv(
    '../data/cleaned/dataset_maderas_final.csv',
    sep=';',
    encoding='utf-8-sig'
)

df.head()
# Out:
#   felling_period  felling_toponymy_source felling_toponymy_MTN25   latitude  \
# 0      1748-1749                   Benahú      Dehesa de Benahú   36.576893
# 1      1748-1749                    Jarda    Dehesa de la Jarda   36.602238
# 2      1748-1749  Barranco de la Fantasma           La Fantasma   36.609978
# 3      1748-1749              La Jardilla           La Jardilla   36.621789
# 4      1748-1749       Garganta de Millán                 Millán  36.616171
#
#    longitude province          municipality landownership  \
# 0  -5.509202    Cádiz  Jerez de la Frontera       comunal
# 1  -5.601913    Cádiz  Jerez de la Frontera     undefined
# 2  -5.464804    Cádiz  Jerez de la Frontera     undefined
# 3  -5.518366    Cádiz  Jerez de la Frontera       comunal
# 4  -5.474945    Cádiz  Jerez de la Frontera     undefined
#
#          landowner_name tree_species  tree_quantity
# 0  Jerez de la Frontera     gall oak          622.0
# 1             undefined     gall oak          230.0
# 2             undefined     gall oak          240.0
# 3  Jerez de la Frontera     gall oak         1457.0
# 4             undefined     gall oak          250.0

# %%
df.head()
# Out:
#   felling_period  felling_toponymy_source felling_toponymy_MTN25   latitude  \
# 0      1748-1749                   Benahú      Dehesa de Benahú   36.576893
# 1      1748-1749                    Jarda    Dehesa de la Jarda   36.602238
# 2      1748-1749  Barranco de la Fantasma           La Fantasma   36.609978
# 3      1748-1749              La Jardilla           La Jardilla   36.621789
# 4      1748-1749       Garganta de Millán                 Millán  36.616171
#
#    longitude province          municipality landownership  \
# 0  -5.509202    Cádiz  Jerez de la Frontera       comunal
# 1  -5.601913    Cádiz  Jerez de la Frontera     undefined
# 2  -5.464804    Cádiz  Jerez de la Frontera     undefined
# 3  -5.518366    Cádiz  Jerez de la Frontera       comunal
# 4  -5.474945    Cádiz  Jerez de la Frontera     undefined
#
#          landowner_name tree_species  tree_quantity
# 0  Jerez de la Frontera     gall oak          622.0
# 1             undefined     gall oak          230.0
# 2             undefined     gall oak          240.0
# 3  Jerez de la Frontera     gall oak         1457.0
# 4             undefined     gall oak          250.0

# %%
list(df.columns)
# Out:
# ['felling_period',
#  'felling_toponymy_source',
#  'felling_toponymy_MTN25',
#  'latitude',
#  'longitude',
#  'province',
#  'municipality',
#  'landownership',
#  'landowner_name',
#  'tree_species',
#  'tree_quantity']

# %% [markdown]
# ## 1. General overview of the dataset

# %%
df.shape
# Out:
# (419, 11)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 419 entries, 0 to 418
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   felling_period           419 non-null    str
#  1   felling_toponymy_source  419 non-null    str
#  2   felling_toponymy_MTN25   419 non-null    str
#  3   latitude                 221 non-null    float64
#  4   longitude                221 non-null    float64
#  5   province                 419 non-null    str
#  6   municipality             419 non-null    str
#  7   landownership            419 non-null    str
#  8   landowner_name           419 non-null    str
#  9   tree_species             419 non-null    str
#  10  tree_quantity            419 non-null    float64
# dtypes: float64(3), str(8)
# memory usage: 70.7 KB

# %%
df.describe(include='all')
# Out:
#        felling_period felling_toponymy_source felling_toponymy_MTN25  \
# count             419                     419                    419
# unique              9                     219                    195
# top         1749-1751                  Utrera                 Utrera
# freq              125                      53                     53
# mean              NaN                     NaN                    NaN
# std               NaN                     NaN                    NaN
# min               NaN                     NaN                    NaN
# 25%               NaN                     NaN                    NaN
# 50%               NaN                     NaN                    NaN
# 75%               NaN                     NaN                    NaN
# max               NaN                     NaN                    NaN
#
#           latitude   longitude province municipality landownership  \
# count   221.000000  221.000000      419          419           419
# unique         NaN         NaN        4           67            12
# top            NaN         NaN  Sevilla       Utrera       private
# freq           NaN         NaN      204           69           164
# mean     37.163315   -6.006347      NaN          NaN           NaN
# std       0.395019    0.903656      NaN          NaN           NaN
# min      36.307821   -7.174165      NaN          NaN           NaN
# 25%      36.799369   -6.364159      NaN          NaN           NaN
# 50%      37.311271   -6.212936      NaN          NaN           NaN
# 75%      37.357908   -5.570802      NaN          NaN           NaN
# max      37.952916    5.538237      NaN          NaN           NaN
#
#        landowner_name tree_species  tree_quantity
# count             419          419     419.000000
# unique            246           10            NaN
# top         undefined         pine            NaN
# freq               25          194            NaN
# mean              NaN          NaN     158.150597
# std               NaN          NaN     438.593936
# min               NaN          NaN       0.000000
# 25%               NaN          NaN       4.000000
# 50%               NaN          NaN      22.000000
# 75%               NaN          NaN     114.000000
# max               NaN          NaN    4198.000000

# %%
df.isna().sum()
# Out:
# felling_period               0
# felling_toponymy_source      0
# felling_toponymy_MTN25       0
# latitude                   198
# longitude                  198
# province                     0
# municipality                 0
# landownership                0
# landowner_name               0
# tree_species                 0
# tree_quantity                0
# dtype: int64

# %%
df[df.isna().any(axis=1)]
# Out:
#     felling_period               felling_toponymy_source  \
# 20       1748-1749              Santa María de Guadalupe
# 24       1748-1750                                 Ronda
# 25       1748-1751                             Castellar
# 26       1748-1751            Dehesa de Alcalá del Valle
# 27       1748-1751  Santa María de Guadalupe / El Bosque
# ..             ...                                   ...
# 391           1751                                  Cala
# 392           1751                                  Cala
# 393           1751                 Santa Olalla del Cala
# 417           1751                             Patronato
# 418           1751                               Baldios
#
#     felling_toponymy_MTN25  latitude  longitude province  \
# 20               El Bosque       NaN        NaN    Cádiz
# 24                   Ronda       NaN        NaN   Málaga
# 25               undefined       NaN        NaN    Cádiz
# 26               undefined       NaN        NaN    Cádiz
# 27               El Bosque       NaN        NaN    Cádiz
# ..                     ...       ...        ...      ...
# 391                   Cala       NaN        NaN   Huelva
# 392                   Cala       NaN        NaN   Huelva
# 393  Santa Olalla del Cala       NaN        NaN   Huelva
# 417              Patronato       NaN        NaN  Sevilla
# 418              undefined       NaN        NaN  Sevilla
#
#                    municipality landownership  \
# 20                    El Bosque  noble estate
# 24                        Ronda       comunal
# 25     Castellar de la Frontera       comunal
# 26             Alcalá del Valle       comunal
# 27                    El Bosque  noble estate
# ..                          ...           ...
# 391                        Cala       comunal
# 392                        Cala       private
# 393       Santa Olalla del Cala       comunal
# 417  El Castillo de las Guardas  ecclesiastic
# 418                  El Garrobo       comunal
#
#                             landowner_name tree_species  tree_quantity
# 20                          Duque de Arcos     gall oak          204.0
# 24                                   Ronda     gall oak         4198.0
# 25                Castellar de la Frontera          oak          898.0
# 26                        Alcalá del Valle          oak         1645.0
# 27                          Duque de Arcos          oak            0.0
# ..                                     ...          ...            ...
# 391            cabildo de la villa de Cala     holm oak          494.0
# 392         Antonio Perez, María Domínguez     holm oak           21.0
# 393                  Santa Olalla del Cala     holm oak          851.0
# 417  Vigario de El Castillo de las Guardas     holm oak          109.0
# 418                             El Garrobo     holm oak           59.0
#
# [198 rows x 11 columns]

# %%
df.sample(5)
# Out:
#     felling_period  felling_toponymy_source felling_toponymy_MTN25   latitude  \
# 159           1749        Pinal de la Plata               La Plata  37.526614
# 15       1748-1749             Moracha Alta             La Moracha  36.508040
# 396           1751       Zerro del Almendro     Cerro del Almendro  37.952916
# 190      1749-1750      Dehesa de Paternina    Dehesa de Paternina  37.333163
# 64            1750  Dehesa de la Granadilla          La Granadilla  36.466734
#
#      longitude province           municipality landownership  \
# 159  -5.760962  Sevilla                Carmona  noble estate
# 15   -5.557695    Cádiz  Alcalá de los Gazules     undefined
# 396  -6.220695   Huelva  Santa Olalla del Cala       private
# 190  -6.424401   Huelva                Chucena       comunal
# 64   -5.570802    Cádiz  Jimena de la Frontera       comunal
#
#             landowner_name        tree_species  tree_quantity
# 159    Marqués de Saltillo                pine            7.0
# 15               undefined  gall oak, cork oak         1406.0
# 396        Juan de Aguilar            holm oak           40.0
# 190    Rociana del Condado            holm oak            7.0
# 64   Jimena de la Frontera  holm oak, gall oak          338.0

# %%
df.nunique()
# Out:
# felling_period               9
# felling_toponymy_source    219
# felling_toponymy_MTN25     195
# latitude                   161
# longitude                  161
# province                     4
# municipality                67
# landownership               12
# landowner_name             246
# tree_species                10
# tree_quantity              162
# dtype: int64

# %%
df.columns
# Out:
# Index(['felling_period', 'felling_toponymy_source', 'felling_toponymy_MTN25',
#        'latitude', 'longitude', 'province', 'municipality', 'landownership',
#        'landowner_name', 'tree_species', 'tree_quantity'],
#       dtype='str')

# %%
df.dtypes
# Out:
# felling_period                 str
# felling_toponymy_source        str
# felling_toponymy_MTN25         str
# latitude                   float64
# longitude                  float64
# province                       str
# municipality                   str
# landownership                  str
# landowner_name                 str
# tree_species                   str
# tree_quantity              float64
# dtype: object

# %%
pd.DataFrame({
    'column': df.columns,
    'unique_values': [df[col].nunique() for col in df.columns]
}).sort_values('unique_values', ascending=False)
# Out:
#                      column  unique_values
# 8            landowner_name            246
# 1   felling_toponymy_source            219
# 2    felling_toponymy_MTN25            195
# 10            tree_quantity            162
# 3                  latitude            161
# 4                 longitude            161
# 6              municipality             67
# 7             landownership             12
# 9              tree_species             10
# 0            felling_period              9
# 5                  province              4

# %% [markdown]
# ## 2. Temporal distribution of tree quantities

# %%
trees_by_period = (
    df.groupby('felling_period')['tree_quantity']
    .sum()
    .sort_values(ascending=False)
)

trees_by_period
# Out:
# felling_period
# 1749-1750    19093.1
# 1748-1749    18006.0
# 1750          8122.0
# 1748-1751     6943.0
# 1748-1750     4641.0
# 1749-1751     4284.0
# 1751          3447.0
# 1749          1183.0
# 1750-1751      546.0
# Name: tree_quantity, dtype: float64

# %% [markdown]
# ## 3. Geographic distribution of tree quantities

# %%
trees_by_province = (
    df.groupby('province')['tree_quantity']
    .sum()
    .sort_values(ascending=False)
)

trees_by_province
# Out:
# province
# Cádiz      32920.1
# Málaga     11888.0
# Sevilla    11056.0
# Huelva     10401.0
# Name: tree_quantity, dtype: float64

# %%
trees_by_municipality = (
    df.groupby('municipality')['tree_quantity']
    .sum()
    .sort_values(ascending=False)
)

trees_by_municipality
# Out:
# municipality
# Cortes de la Frontera     7599.0
# Jimena de la Frontera     7545.0
# Jerez de la Frontera      6467.1
# Alcalá del Valle          5238.0
# Ronda                     4289.0
#                            ...
# Paradas                     13.0
# Espartinas                   1.0
# Arahal                       1.0
# Los Molares                  1.0
# Villanueva del Ariscal       1.0
# Name: tree_quantity, Length: 67, dtype: float64

# %%
trees_by_toponymy_source = (
    df.groupby('felling_toponymy_source')['tree_quantity']
    .sum()
    .sort_values(ascending=False)
)

trees_by_toponymy_source
# Out:
# felling_toponymy_source
# Ronda                                   4289.0
# Dehesa del Tomillo                      3593.0
# Ubrique                                 3150.0
# Sauceda                                 2986.0
# Dehesa de Buenas Noches                 2847.0
#                                          ...
# Loma de la Peña                            0.0
# Monte de la Zarza                          0.0
# Moros                                      0.0
# Santa María de Guadalupe / El Bosque       0.0
# Tronco                                     0.0
# Name: tree_quantity, Length: 219, dtype: float64

# %%
province_municipality_source_trees = (
    df.groupby(
        [
            'province',
            'municipality',
            'felling_toponymy_source'
        ]
    )['tree_quantity']
    .sum()
    .reset_index()
)

province_totals = (
    province_municipality_source_trees.groupby('province')['tree_quantity']
    .sum()
    .reset_index()
    .rename(columns={'tree_quantity': 'province_total'})
)

municipality_totals = (
    province_municipality_source_trees.groupby(['province', 'municipality'])['tree_quantity']
    .sum()
    .reset_index()
    .rename(columns={'tree_quantity': 'municipality_total'})
)

province_municipality_source_trees = province_municipality_source_trees.merge(
    province_totals,
    on='province'
)

province_municipality_source_trees = province_municipality_source_trees.merge(
    municipality_totals,
    on=['province', 'municipality']
)

province_municipality_source_trees = province_municipality_source_trees.sort_values(
    by=[
        'province_total',
        'municipality_total',
        'tree_quantity'
    ],
    ascending=[False, False, False]
)

province_municipality_source_trees
# Out:
#     province           municipality  felling_toponymy_source  tree_quantity  \
# 41     Cádiz  Jimena de la Frontera  Dehesa de Buenas Noches         2847.0
# 39     Cádiz  Jimena de la Frontera        Baldíos de Jimena         2120.0
# 40     Cádiz  Jimena de la Frontera     Cuesta de Huevo Duro          448.0
# 42     Cádiz  Jimena de la Frontera      Dehesa de la Goleta          448.0
# 44     Cádiz  Jimena de la Frontera          Exes de Moracha          448.0
# ..       ...                    ...                      ...            ...
# 96    Huelva                 Moguer                   Moguer           36.0
# 84    Huelva              Gibraleón             Los Millares           30.0
# 83    Huelva                 Gelves             Torrequemada           23.0
# 103   Huelva    San Juan del Puerto                   Candón           13.0
# 104   Huelva    San Juan del Puerto                  Toconal            6.0
#
#      province_total  municipality_total
# 41          32920.1              7545.0
# 39          32920.1              7545.0
# 40          32920.1              7545.0
# 42          32920.1              7545.0
# 44          32920.1              7545.0
# ..              ...                 ...
# 96          10401.0                36.0
# 84          10401.0                30.0
# 83          10401.0                23.0
# 103         10401.0                19.0
# 104         10401.0                19.0
#
# [226 rows x 6 columns]

# %% [markdown]
# ## 4. Spatio-temporal distribution of tree quantities

# %%
period_province_municipality_trees = (
    df.groupby(
        [
            'felling_period',
            'province',
            'municipality'
        ]
    )['tree_quantity']
    .sum()
    .reset_index()
)

period_totals = (
    period_province_municipality_trees.groupby('felling_period')['tree_quantity']
    .sum()
    .reset_index()
    .rename(columns={'tree_quantity': 'period_total'})
)

province_totals_within_period = (
    period_province_municipality_trees.groupby(['felling_period', 'province'])['tree_quantity']
    .sum()
    .reset_index()
    .rename(columns={'tree_quantity': 'province_total'})
)

period_province_municipality_trees = period_province_municipality_trees.merge(
    period_totals,
    on='felling_period'
)

period_province_municipality_trees = period_province_municipality_trees.merge(
    province_totals_within_period,
    on=['felling_period', 'province']
)

period_province_municipality_trees = period_province_municipality_trees.sort_values(
    by=[
        'period_total',
        'province_total',
        'tree_quantity'
    ],
    ascending=[False, False, False]
)

period_province_municipality_trees
# Out:
#     felling_period province               municipality  tree_quantity  \
# 58       1749-1750    Cádiz           Alcalá del Valle         3593.0
# 61       1749-1750    Cádiz                  Grazalema         2353.0
# 62       1749-1750    Cádiz       Jerez de la Frontera         2284.1
# 63       1749-1750    Cádiz      Jimena de la Frontera         2240.0
# 65       1749-1750    Cádiz        Zahara de la Sierra          191.0
# ..             ...      ...                        ...            ...
# 48            1749   Málaga      Cortes de la Frontera            0.0
# 123      1750-1751   Huelva  San Bartolomé de la Torre          204.0
# 122      1750-1751   Huelva                    Almonte          103.0
# 121      1750-1751    Cádiz       Jerez de la Frontera          238.0
# 124      1750-1751  Sevilla                     Utrera            1.0
#
#      period_total  province_total
# 58        19093.1         10985.1
# 61        19093.1         10985.1
# 62        19093.1         10985.1
# 63        19093.1         10985.1
# 65        19093.1         10985.1
# ..            ...             ...
# 48         1183.0             0.0
# 123         546.0           307.0
# 122         546.0           307.0
# 121         546.0           238.0
# 124         546.0             1.0
#
# [143 rows x 6 columns]

# %%
period_province_municipality_trees = (
    df.groupby(
        [
            'felling_period',
            'province',
            'municipality'
        ]
    )['tree_quantity']
    .sum()
    .reset_index()
)

province_totals_within_period = (
    period_province_municipality_trees.groupby(['felling_period', 'province'])['tree_quantity']
    .sum()
    .reset_index()
    .rename(columns={'tree_quantity': 'province_total'})
)

period_province_municipality_trees = period_province_municipality_trees.merge(
    province_totals_within_period,
    on=['felling_period', 'province']
)

period_province_municipality_trees = period_province_municipality_trees.sort_values(
    by=[
        'felling_period',
        'province_total',
        'tree_quantity'
    ],
    ascending=[True, False, False]
)

period_province_municipality_trees
# Out:
#     felling_period province                 municipality  tree_quantity  \
# 3        1748-1749    Cádiz         Jerez de la Frontera         2799.0
# 2        1748-1749    Cádiz                    Grazalema         1510.0
# 0        1748-1749    Cádiz        Alcalá de los Gazules         1406.0
# 4        1748-1749    Cádiz                Prado del Rey          953.0
# 5        1748-1749    Cádiz          Zahara de la Sierra          740.0
# ..             ...      ...                          ...            ...
# 139           1751  Sevilla            La Puebla del Río           39.0
# 138           1751  Sevilla                       Huévar           37.0
# 141           1751  Sevilla                      Umbrete           28.0
# 142           1751  Sevilla  Villamanrique de la Condesa           25.0
# 134           1751  Sevilla     Bollullos de la Mitación           21.0
#
#      province_total
# 3            7612.0
# 2            7612.0
# 0            7612.0
# 4            7612.0
# 5            7612.0
# ..              ...
# 139          1326.0
# 138          1326.0
# 141          1326.0
# 142          1326.0
# 134          1326.0
#
# [143 rows x 5 columns]

# %% [markdown]
# ## 5. Distribution of tree species by quantity

# %%
trees_by_species = (
    df.groupby('tree_species')['tree_quantity']
    .sum()
    .sort_values(ascending=False)
)

trees_by_species
# Out:
# tree_species
# oak                   18108.0
# holm oak              15990.0
# gall oak              13233.1
# undefined species      6055.0
# pine                   5358.0
# gall oak, cork oak     4392.0
# holm oak, gall oak     2775.0
# cork oak                311.0
# olive                    43.0
# oak, gall oak             0.0
# Name: tree_quantity, dtype: float64

# %%
period_species_trees = (
    df.groupby(
        [
            'felling_period',
            'tree_species'
        ]
    )['tree_quantity']
    .sum()
    .reset_index()
)

period_species_trees = period_species_trees.sort_values(
    by=[
        'felling_period',
        'tree_quantity'
    ],
    ascending=[True, False]
)

period_species_trees
# Out:
#    felling_period        tree_species  tree_quantity
# 4       1748-1749   undefined species         5356.0
# 2       1748-1749            holm oak         5039.0
# 1       1748-1749  gall oak, cork oak         4392.0
# 0       1748-1749            gall oak         3003.0
# 3       1748-1749                pine          216.0
# 5       1748-1750            gall oak         4198.0
# 8       1748-1750   undefined species          370.0
# 6       1748-1750            holm oak           66.0
# 7       1748-1750                pine            7.0
# 9       1748-1751                 oak         5693.0
# 10      1748-1751                pine         1159.0
# 11      1748-1751   undefined species           91.0
# 12           1749            holm oak          925.0
# 13           1749                pine          258.0
# 14           1749   undefined species            0.0
# 19      1749-1750                 oak         8891.0
# 17      1749-1750            holm oak         5387.0
# 18      1749-1750  holm oak, gall oak         2270.0
# 16      1749-1750            gall oak         2039.1
# 15      1749-1750            cork oak          311.0
# 21      1749-1750                pine          152.0
# 20      1749-1750               olive           43.0
# 23      1749-1751                pine         3462.0
# 22      1749-1751            holm oak          822.0
# 24           1750            gall oak         3993.0
# 27           1750                 oak         3524.0
# 26           1750  holm oak, gall oak          505.0
# 25           1750            holm oak          100.0
# 28           1750       oak, gall oak            0.0
# 31      1750-1751   undefined species          238.0
# 29      1750-1751            holm oak          204.0
# 30      1750-1751                pine          104.0
# 32           1751            holm oak         3447.0

# %% [markdown]
# ## 6. Geographic distribution of tree species by quantity

# %%
province_species_trees = (
    df.groupby(['province', 'tree_species'])['tree_quantity']
    .sum()
    .reset_index()
)

province_totals = (
    province_species_trees.groupby('province')['tree_quantity']
    .sum()
    .reset_index()
    .rename(columns={'tree_quantity': 'province_total'})
)

province_species_trees = province_species_trees.merge(
    province_totals,
    on='province'
)

province_species_trees = province_species_trees.sort_values(
    by=['province_total', 'tree_quantity'],
    ascending=[False, False]
)

province_species_trees
# Out:
#    province        tree_species  tree_quantity  province_total
# 4     Cádiz                 oak        15678.0         32920.1
# 1     Cádiz            gall oak         9035.1         32920.1
# 6     Cádiz   undefined species         3811.0         32920.1
# 3     Cádiz  holm oak, gall oak         2745.0         32920.1
# 2     Cádiz  gall oak, cork oak         1406.0         32920.1
# 0     Cádiz            cork oak          245.0         32920.1
# 5     Cádiz       oak, gall oak            0.0         32920.1
# 11   Málaga            gall oak         4198.0         11888.0
# 12   Málaga  gall oak, cork oak         2986.0         11888.0
# 14   Málaga                 oak         2430.0         11888.0
# 15   Málaga   undefined species         2244.0         11888.0
# 13   Málaga  holm oak, gall oak           30.0         11888.0
# 16  Sevilla            holm oak         8667.0         11056.0
# 17  Sevilla                pine         2389.0         11056.0
# 8    Huelva            holm oak         7323.0         10401.0
# 10   Huelva                pine         2969.0         10401.0
# 7    Huelva            cork oak           66.0         10401.0
# 9    Huelva               olive           43.0         10401.0

# %%
province_municipality_species_trees = (
    df.groupby(['province', 'municipality', 'tree_species'])['tree_quantity']
    .sum()
    .reset_index()
)

province_totals = (
    province_municipality_species_trees.groupby('province')['tree_quantity']
    .sum()
    .reset_index()
    .rename(columns={'tree_quantity': 'province_total'})
)

municipality_totals_within_province = (
    province_municipality_species_trees.groupby(['province', 'municipality'])['tree_quantity']
    .sum()
    .reset_index()
    .rename(columns={'tree_quantity': 'municipality_total'})
)

province_municipality_species_trees = province_municipality_species_trees.merge(
    province_totals,
    on='province'
)

province_municipality_species_trees = province_municipality_species_trees.merge(
    municipality_totals_within_province,
    on=['province', 'municipality']
)

province_municipality_species_trees = province_municipality_species_trees.sort_values(
    by=['province_total', 'municipality_total', 'tree_quantity'],
    ascending=[False, False, False]
)

province_municipality_species_trees
# Out:
#    province           municipality        tree_species  tree_quantity  \
# 14    Cádiz  Jimena de la Frontera            gall oak         2847.0
# 15    Cádiz  Jimena de la Frontera  holm oak, gall oak         2578.0
# 16    Cádiz  Jimena de la Frontera                 oak         2120.0
# 17    Cádiz  Jimena de la Frontera       oak, gall oak            0.0
# 12    Cádiz   Jerez de la Frontera            gall oak         5984.1
# ..      ...                    ...                 ...            ...
# 38   Huelva                 Huelva            holm oak           41.0
# 41   Huelva                 Moguer                pine           36.0
# 35   Huelva              Gibraleón            holm oak           30.0
# 34   Huelva                 Gelves                pine           23.0
# 47   Huelva    San Juan del Puerto            holm oak           19.0
#
#     province_total  municipality_total
# 14         32920.1              7545.0
# 15         32920.1              7545.0
# 16         32920.1              7545.0
# 17         32920.1              7545.0
# 12         32920.1              6467.1
# ..             ...                 ...
# 38         10401.0                41.0
# 41         10401.0                36.0
# 35         10401.0                30.0
# 34         10401.0                23.0
# 47         10401.0                19.0
#
# [99 rows x 6 columns]

# %% [markdown]
# ## 7. Distribution of landownership types and landowners by tree quantity

# %%
trees_by_landownership = (
    df.groupby('landownership')['tree_quantity']
    .sum()
    .sort_values(ascending=False)
)

trees_by_landownership
# Out:
# landownership
# comunal                       28848.1
# noble estate                  16106.0
# undefined                      7761.0
# private                        7726.0
# ecclesiastic                   2229.0
# fallow land                    2193.0
# assistance institution         1001.0
# private, ecclesiastic           252.0
# noble estate, ecclesiastic       83.0
# private, comunal                 31.0
# comunal, ecclesiastic            29.0
# private, noble estate             6.0
# Name: tree_quantity, dtype: float64

# %%
trees_by_landowner = (
    df.groupby('landowner_name')['tree_quantity']
    .sum()
    .sort_values(ascending=False)
)

trees_by_landowner
# Out:
# landowner_name
# undefined                8016.0
# Jerez de la Frontera     5509.1
# Jimena de la Frontera    4698.0
# Ronda                    4289.0
# Duque de Arcos           3682.0
#                           ...
# María Lamilla               1.0
# Pedro Ordiales              1.0
# Pedro Mendez                1.0
# Utrera                      1.0
# Diego de Guzmán             0.0
# Name: tree_quantity, Length: 246, dtype: float64

# %%
landownership_landowner_trees = (
    df.groupby(
        [
            'landownership',
            'landowner_name'
        ]
    )['tree_quantity']
    .sum()
    .reset_index()
)

landownership_totals = (
    landownership_landowner_trees.groupby('landownership')['tree_quantity']
    .sum()
    .reset_index()
    .rename(columns={'tree_quantity': 'landownership_total'})
)

landownership_landowner_trees = landownership_landowner_trees.merge(
    landownership_totals,
    on='landownership'
)

landownership_landowner_trees = landownership_landowner_trees.sort_values(
    by=[
        'landownership_total',
        'tree_quantity'
    ],
    ascending=[False, False]
)

landownership_landowner_trees
# Out:
#                   landownership  \
# 23                      comunal
# 29                      comunal
# 34                      comunal
# 24                      comunal
# 16                      comunal
# ..                          ...
# 247       private, ecclesiastic
# 105  noble estate, ecclesiastic
# 245            private, comunal
# 42        comunal, ecclesiastic
# 249       private, noble estate
#
#                                         landowner_name  tree_quantity  \
# 23                                Jerez de la Frontera         5509.1
# 29                                               Ronda         4289.0
# 34                                             Ubrique         3150.0
# 24                               Jimena de la Frontera         2578.0
# 16                               Cortes de la Frontera         2460.0
# ..                                                 ...            ...
# 247  Juan Gallardo, Julio Cavaleri, Convento de San...            6.0
# 105  Marquesa de La Motilla, Convento de San Pablo ...           83.0
# 245  Alonso Pérez Mota, Francisco José Vayas, Ferna...           31.0
# 42   Lucena del Puerto, Convento de la Luz de Lucen...           29.0
# 249                    Pedro Morales, Marqués de Caozo            6.0
#
#      landownership_total
# 23               28848.1
# 29               28848.1
# 34               28848.1
# 24               28848.1
# 16               28848.1
# ..                   ...
# 247                252.0
# 105                 83.0
# 245                 31.0
# 42                  29.0
# 249                  6.0
#
# [251 rows x 4 columns]

# %% [markdown]
# ## 8. Geographic distribution of landowners and landownership types

# %%
province_landowner_trees = (
    df.groupby(['province', 'landowner_name'])['tree_quantity']
    .sum()
    .reset_index()
)

province_totals = (
    province_landowner_trees.groupby('province')['tree_quantity']
    .sum()
    .reset_index()
    .rename(columns={'tree_quantity': 'province_total'})
)

province_landowner_trees = province_landowner_trees.merge(
    province_totals,
    on='province'
)

province_landowner_trees = province_landowner_trees.sort_values(
    by=['province_total', 'tree_quantity'],
    ascending=[False, False]
)

province_landowner_trees
# Out:
#    province                       landowner_name  tree_quantity  \
# 10    Cádiz                            undefined         5567.0
# 6     Cádiz                 Jerez de la Frontera         5509.1
# 7     Cádiz                Jimena de la Frontera         4698.0
# 3     Cádiz                       Duque de Arcos         3676.0
# 8     Cádiz                  Marqués de Benamejí         3593.0
# ..      ...                                  ...            ...
# 47   Huelva                    Francisco de Vega            2.0
# 52   Huelva  Hermita de Nuestra Señora del Rocío            2.0
# 58   Huelva                 Josefa María Venegas            2.0
# 40   Huelva        Fabrica de la Iglesia de Cala            1.0
# 31   Huelva                      Diego de Guzmán            0.0
#
#     province_total
# 10         32920.1
# 6          32920.1
# 7          32920.1
# 3          32920.1
# 8          32920.1
# ..             ...
# 47         10401.0
# 52         10401.0
# 58         10401.0
# 40         10401.0
# 31         10401.0
#
# [253 rows x 4 columns]

# %%
province_landownership_trees = (
    df.groupby(['province', 'landownership'])['tree_quantity']
    .sum()
    .reset_index()
)

province_totals = (
    province_landownership_trees.groupby('province')['tree_quantity']
    .sum()
    .reset_index()
    .rename(columns={'tree_quantity': 'province_total'})
)

province_landownership_trees = province_landownership_trees.merge(
    province_totals,
    on='province'
)

province_landownership_trees = province_landownership_trees.sort_values(
    by=['province_total', 'tree_quantity'],
    ascending=[False, False]
)

province_landownership_trees
# Out:
#    province               landownership  tree_quantity  province_total
# 0     Cádiz                     comunal        14004.1         32920.1
# 2     Cádiz                noble estate        11229.0         32920.1
# 3     Cádiz                   undefined         5567.0         32920.1
# 1     Cádiz                 fallow land         2120.0         32920.1
# 15   Málaga                     comunal         6749.0         11888.0
# 16   Málaga                     private         2986.0         11888.0
# 17   Málaga                   undefined         2153.0         11888.0
# 22  Sevilla                noble estate         2992.0         11056.0
# 19  Sevilla                     comunal         2798.0         11056.0
# 23  Sevilla                     private         2238.0         11056.0
# 20  Sevilla                ecclesiastic         1928.0         11056.0
# 18  Sevilla      assistance institution          978.0         11056.0
# 24  Sevilla       private, ecclesiastic          104.0         11056.0
# 21  Sevilla                 fallow land           12.0         11056.0
# 25  Sevilla       private, noble estate            6.0         11056.0
# 5    Huelva                     comunal         5297.0         10401.0
# 11   Huelva                     private         2502.0         10401.0
# 9    Huelva                noble estate         1885.0         10401.0
# 7    Huelva                ecclesiastic          301.0         10401.0
# 13   Huelva       private, ecclesiastic          148.0         10401.0
# 10   Huelva  noble estate, ecclesiastic           83.0         10401.0
# 8    Huelva                 fallow land           61.0         10401.0
# 14   Huelva                   undefined           41.0         10401.0
# 12   Huelva            private, comunal           31.0         10401.0
# 6    Huelva       comunal, ecclesiastic           29.0         10401.0
# 4    Huelva      assistance institution           23.0         10401.0

# %%
province_municipality_landowner_trees = (
    df.groupby(['province', 'municipality', 'landowner_name'])['tree_quantity']
    .sum()
    .reset_index()
)

province_totals = (
    province_municipality_landowner_trees.groupby('province')['tree_quantity']
    .sum()
    .reset_index()
    .rename(columns={'tree_quantity': 'province_total'})
)

municipality_totals_within_province = (
    province_municipality_landowner_trees.groupby(['province', 'municipality'])['tree_quantity']
    .sum()
    .reset_index()
    .rename(columns={'tree_quantity': 'municipality_total'})
)

province_municipality_landowner_trees = province_municipality_landowner_trees.merge(
    province_totals,
    on='province'
)

province_municipality_landowner_trees = province_municipality_landowner_trees.merge(
    municipality_totals_within_province,
    on=['province', 'municipality']
)

province_municipality_landowner_trees = province_municipality_landowner_trees.sort_values(
    by=['province_total', 'municipality_total', 'tree_quantity'],
    ascending=[False, False, False]
)

province_municipality_landowner_trees
# Out:
#     province           municipality                      landowner_name  \
# 15     Cádiz  Jimena de la Frontera               Jimena de la Frontera
# 14     Cádiz  Jimena de la Frontera             Duque de Medina Sidonia
# 12     Cádiz   Jerez de la Frontera                Jerez de la Frontera
# 13     Cádiz   Jerez de la Frontera                           undefined
# 3      Cádiz       Alcalá del Valle                 Marqués de Benamejí
# ..       ...                    ...                                 ...
# 106   Huelva                 Huelva                     Diego de Guzmán
# 112   Huelva                 Moguer                          Manuel Gil
# 77    Huelva              Gibraleón                      Duque de Béjar
# 76    Huelva                 Gelves  Hospicio de San Ignacio de Sevilla
# 118   Huelva    San Juan del Puerto                 San Juan del Puerto
#
#      tree_quantity  province_total  municipality_total
# 15          4698.0         32920.1              7545.0
# 14          2847.0         32920.1              7545.0
# 12          5509.1         32920.1              6467.1
# 13           958.0         32920.1              6467.1
# 3           3593.0         32920.1              5238.0
# ..             ...             ...                 ...
# 106            0.0         10401.0                41.0
# 112           36.0         10401.0                36.0
# 77            30.0         10401.0                30.0
# 76            23.0         10401.0                23.0
# 118           19.0         10401.0                19.0
#
# [290 rows x 6 columns]

# %%
province_municipality_landownership_trees = (
    df.groupby(['province', 'municipality', 'landownership'])['tree_quantity']
    .sum()
    .reset_index()
)

province_totals = (
    province_municipality_landownership_trees.groupby('province')['tree_quantity']
    .sum()
    .reset_index()
    .rename(columns={'tree_quantity': 'province_total'})
)

municipality_totals_within_province = (
    province_municipality_landownership_trees.groupby(['province', 'municipality'])['tree_quantity']
    .sum()
    .reset_index()
    .rename(columns={'tree_quantity': 'municipality_total'})
)

province_municipality_landownership_trees = province_municipality_landownership_trees.merge(
    province_totals,
    on='province'
)

province_municipality_landownership_trees = province_municipality_landownership_trees.merge(
    municipality_totals_within_province,
    on=['province', 'municipality']
)

province_municipality_landownership_trees = province_municipality_landownership_trees.sort_values(
    by=['province_total', 'municipality_total', 'tree_quantity'],
    ascending=[False, False, False]
)

province_municipality_landownership_trees
# Out:
#    province           municipality           landownership  tree_quantity  \
# 16    Cádiz  Jimena de la Frontera            noble estate         2847.0
# 14    Cádiz  Jimena de la Frontera                 comunal         2578.0
# 15    Cádiz  Jimena de la Frontera             fallow land         2120.0
# 12    Cádiz   Jerez de la Frontera                 comunal         5509.1
# 13    Cádiz   Jerez de la Frontera               undefined          958.0
# ..      ...                    ...                     ...            ...
# 52   Huelva                 Huelva                 private            0.0
# 58   Huelva                 Moguer                 private           36.0
# 44   Huelva              Gibraleón            noble estate           30.0
# 43   Huelva                 Gelves  assistance institution           23.0
# 63   Huelva    San Juan del Puerto                 comunal           19.0
#
#     province_total  municipality_total
# 16         32920.1              7545.0
# 14         32920.1              7545.0
# 15         32920.1              7545.0
# 12         32920.1              6467.1
# 13         32920.1              6467.1
# ..             ...                 ...
# 52         10401.0                41.0
# 58         10401.0                36.0
# 44         10401.0                30.0
# 43         10401.0                23.0
# 63         10401.0                19.0
#
# [142 rows x 6 columns]

# %% [markdown]
# ## 9. Distribution of tree species by landownership type

# %%
landownership_species_trees = (
    df.groupby(
        [
            'landownership',
            'tree_species'
        ]
    )['tree_quantity']
    .sum()
    .reset_index()
)

landownership_totals = (
    landownership_species_trees.groupby('landownership')['tree_quantity']
    .sum()
    .reset_index()
    .rename(columns={'tree_quantity': 'landownership_total'})
)

landownership_species_trees = landownership_species_trees.merge(
    landownership_totals,
    on='landownership'
)

landownership_species_trees = landownership_species_trees.sort_values(
    by=[
        'landownership_total',
        'tree_quantity'
    ],
    ascending=[False, False]
)

landownership_species_trees
# Out:
#                  landownership        tree_species  tree_quantity  \
# 3                      comunal            gall oak         9462.1
# 6                      comunal                 oak         8180.0
# 4                      comunal            holm oak         7613.0
# 5                      comunal  holm oak, gall oak         2775.0
# 8                      comunal                pine          416.0
# 2                      comunal            cork oak          311.0
# 9                      comunal   undefined species           91.0
# 7                      comunal       oak, gall oak            0.0
# 17                noble estate                 oak         7808.0
# 16                noble estate            holm oak         3723.0
# 15                noble estate            gall oak         3051.0
# 18                noble estate                pine         1154.0
# 19                noble estate   undefined species          370.0
# 32                   undefined   undefined species         5594.0
# 30                   undefined  gall oak, cork oak         1406.0
# 29                   undefined            gall oak          720.0
# 31                   undefined            holm oak           41.0
# 21                     private  gall oak, cork oak         2986.0
# 24                     private                pine         2718.0
# 22                     private            holm oak         1979.0
# 23                     private               olive           43.0
# 25                     private   undefined species            0.0
# 11                ecclesiastic            holm oak         1815.0
# 12                ecclesiastic                pine          414.0
# 14                 fallow land                 oak         2120.0
# 13                 fallow land            holm oak           73.0
# 0       assistance institution            holm oak          634.0
# 1       assistance institution                pine          367.0
# 27       private, ecclesiastic                pine          252.0
# 20  noble estate, ecclesiastic            holm oak           83.0
# 26            private, comunal                pine           31.0
# 10       comunal, ecclesiastic            holm oak           29.0
# 28       private, noble estate                pine            6.0
#
#     landownership_total
# 3               28848.1
# 6               28848.1
# 4               28848.1
# 5               28848.1
# 8               28848.1
# 2               28848.1
# 9               28848.1
# 7               28848.1
# 17              16106.0
# 16              16106.0
# 15              16106.0
# 18              16106.0
# 19              16106.0
# 32               7761.0
# 30               7761.0
# 29               7761.0
# 31               7761.0
# 21               7726.0
# 24               7726.0
# 22               7726.0
# 23               7726.0
# 25               7726.0
# 11               2229.0
# 12               2229.0
# 14               2193.0
# 13               2193.0
# 0                1001.0
# 1                1001.0
# 27                252.0
# 20                 83.0
# 26                 31.0
# 10                 29.0
# 28                  6.0

# %% [markdown]
# ## 10. Number of properties by landowner and landownership type

# %%
landownership_toponymy = (
    df[
        (df['latitude'] != 0) &
        (df['longitude'] != 0)
    ]
    .groupby(
        [
            'landownership',
            'felling_toponymy_source'
        ]
    )['tree_quantity']
    .sum()
    .reset_index()
)

landownership_totals = (
    landownership_toponymy.groupby('landownership')['tree_quantity']
    .sum()
    .reset_index()
    .rename(columns={'tree_quantity': 'landownership_total'})
)

landownership_toponymy = landownership_toponymy.merge(
    landownership_totals,
    on='landownership'
)

landownership_toponymy = landownership_toponymy.sort_values(
    by=[
        'landownership_total',
        'tree_quantity'
    ],
    ascending=[False, False]
)

landownership_toponymy
# Out:
#                   landownership            felling_toponymy_source  \
# 72                      comunal                              Ronda
# 76                      comunal                            Ubrique
# 24                      comunal         Dehesa de Alcalá del Valle
# 62                      comunal                        La Jardilla
# 29                      comunal  Dehesa de Castillo de las Guardas
# ..                          ...                                ...
# 168  noble estate, ecclesiastic         Dehesa de Torre de Quadros
# 169  noble estate, ecclesiastic                   Torre de Quadros
# 223            private, comunal                            Hinojos
# 81        comunal, ecclesiastic                Dehesa de Pormedias
# 228       private, noble estate                          El Caosso
#
#      tree_quantity  landownership_total
# 72          4289.0              28848.1
# 76          3150.0              28848.1
# 24          1645.0              28848.1
# 62          1577.0              28848.1
# 29          1165.0              28848.1
# ..             ...                  ...
# 168           56.0                 83.0
# 169           27.0                 83.0
# 223           31.0                 31.0
# 81            29.0                 29.0
# 228            6.0                  6.0
#
# [247 rows x 4 columns]

# %%
landowner_toponymy = (
    df[
        (df['latitude'] != 0) &
        (df['longitude'] != 0)
    ]
    .groupby(
        [
            'landowner_name',
            'felling_toponymy_source'
        ]
    )['tree_quantity']
    .sum()
    .reset_index()
)

landowner_totals = (
    landowner_toponymy.groupby('landowner_name')['tree_quantity']
    .sum()
    .reset_index()
    .rename(columns={'tree_quantity': 'landowner_total'})
)

landowner_toponymy = landowner_toponymy.merge(
    landowner_totals,
    on='landowner_name'
)

landowner_toponymy = landowner_toponymy.sort_values(
    by=[
        'landowner_total',
        'tree_quantity'
    ],
    ascending=[False, False]
)

landowner_toponymy
# Out:
#       landowner_name      felling_toponymy_source  tree_quantity  \
# 363        undefined                 Moracha Alta         1406.0
# 347        undefined                     Bañuelos         1300.0
# 351        undefined                  Chorreadero          740.0
# 353        undefined                   El Canchal          740.0
# 364        undefined        Puerto de las Encinas          533.0
# ..               ...                          ...            ...
# 302    Pedro Briones                    Vera Cruz            1.0
# 305     Pedro Mendez                       Utrera            1.0
# 307   Pedro Ordiales                       Utrera            1.0
# 332           Utrera                       Utrera            1.0
# 79   Diego de Guzmán  Dehesa de Torre de Palencia            0.0
#
#      landowner_total
# 363           8016.0
# 347           8016.0
# 351           8016.0
# 353           8016.0
# 364           8016.0
# ..               ...
# 302              1.0
# 305              1.0
# 307              1.0
# 332              1.0
# 79               0.0
#
# [369 rows x 4 columns]

# %%
properties_by_landownership = (
    df[
        (df['latitude'] != 0) &
        (df['longitude'] != 0)
    ]
    .groupby('landownership')['felling_toponymy_source']
    .nunique()
    .sort_values(ascending=False)
)

properties_by_landownership
# Out:
# landownership
# comunal                       76
# noble estate                  61
# private                       53
# ecclesiastic                  22
# undefined                     18
# assistance institution         5
# private, ecclesiastic          4
# fallow land                    3
# noble estate, ecclesiastic     2
# comunal, ecclesiastic          1
# private, comunal               1
# private, noble estate          1
# Name: felling_toponymy_source, dtype: int64

# %%
properties_by_landowner = (
    df[
        (df['latitude'] != 0) &
        (df['longitude'] != 0)
    ]
    .groupby('landowner_name')['felling_toponymy_source']
    .nunique()
    .sort_values(ascending=False)
)

properties_by_landowner
# Out:
# landowner_name
# undefined                                     23
# Jimena de la Frontera                         14
# Jerez de la Frontera                          13
# Duque de Arcos                                12
# Marqués de Saltillo                            7
#                                               ..
# Vigario de El Castillo de las Guardas          1
# Villanueva de las Cruces                       1
# Widow of Miguel Lamilla, Compañía de Jesus     1
# Zufre                                          1
# cabildo de la villa de Cala                    1
# Name: felling_toponymy_source, Length: 246, dtype: int64

# %% [markdown]
# ## 11. Geographic coordinates and map preparation

# %%
georeferenced_records = df[
    (df['latitude'] != 0) &
    (df['longitude'] != 0)
]

georeferenced_records.head()
# Out:
#   felling_period  felling_toponymy_source felling_toponymy_MTN25   latitude  \
# 0      1748-1749                   Benahú      Dehesa de Benahú   36.576893
# 1      1748-1749                    Jarda    Dehesa de la Jarda   36.602238
# 2      1748-1749  Barranco de la Fantasma           La Fantasma   36.609978
# 3      1748-1749              La Jardilla           La Jardilla   36.621789
# 4      1748-1749       Garganta de Millán                 Millán  36.616171
#
#    longitude province          municipality landownership  \
# 0  -5.509202    Cádiz  Jerez de la Frontera       comunal
# 1  -5.601913    Cádiz  Jerez de la Frontera     undefined
# 2  -5.464804    Cádiz  Jerez de la Frontera     undefined
# 3  -5.518366    Cádiz  Jerez de la Frontera       comunal
# 4  -5.474945    Cádiz  Jerez de la Frontera     undefined
#
#          landowner_name tree_species  tree_quantity
# 0  Jerez de la Frontera     gall oak          622.0
# 1             undefined     gall oak          230.0
# 2             undefined     gall oak          240.0
# 3  Jerez de la Frontera     gall oak         1457.0
# 4             undefined     gall oak          250.0

# %%
print("Records with coordinates:", len(georeferenced_records))
print("Total records:", len(df))
print("Percentage with coordinates:", round(len(georeferenced_records) / len(df) * 100, 2), "%")
# Out:
# Records with coordinates: 419
# Total records: 419
# Percentage with coordinates: 100.0 %

# %%
print("Unique georeferenced places:", georeferenced_records['felling_toponymy_source'].nunique())
# Out:
# Unique georeferenced places: 219

# %%
georeferenced_records.groupby('province')['felling_toponymy_source'] \
    .nunique() \
    .sort_values(ascending=False)
# Out:
# province
# Sevilla    95
# Cádiz      59
# Huelva     57
# Málaga     11
# Name: felling_toponymy_source, dtype: int64

# %%
georeferenced_records.groupby('municipality')['felling_toponymy_source'] \
    .nunique() \
    .sort_values(ascending=False)
# Out:
# municipality
# Jerez de la Frontera          19
# Carmona                       18
# Jimena de la Frontera         15
# Utrera                        14
# El Castillo de las Guardas    11
#                               ..
# Sanlúcar la Mayor              1
# Sevilla                        1
# Valverde del Camino            1
# Villanueva de las Cruces       1
# Villanueva del Ariscal         1
# Name: felling_toponymy_source, Length: 67, dtype: int64

# %%
georeferenced_records.groupby('tree_species')['felling_toponymy_source'] \
    .nunique() \
    .sort_values(ascending=False)
# Out:
# tree_species
# holm oak              98
# pine                  58
# oak                   22
# gall oak              18
# undefined species     15
# holm oak, gall oak     8
# oak, gall oak          7
# cork oak               2
# gall oak, cork oak     2
# olive                  1
# Name: felling_toponymy_source, dtype: int64

# %%
georeferenced_records.groupby('landownership')['felling_toponymy_source'] \
    .nunique() \
    .sort_values(ascending=False)
# Out:
# landownership
# comunal                       76
# noble estate                  61
# private                       53
# ecclesiastic                  22
# undefined                     18
# assistance institution         5
# private, ecclesiastic          4
# fallow land                    3
# noble estate, ecclesiastic     2
# comunal, ecclesiastic          1
# private, comunal               1
# private, noble estate          1
# Name: felling_toponymy_source, dtype: int64

# %%
map_points = georeferenced_records[
    [
        'felling_period',
        'felling_toponymy_source',
        'felling_toponymy_MTN25',
        'province',
        'municipality',
        'landownership',
        'landowner_name',
        'tree_species',
        'tree_quantity',
        'latitude',
        'longitude'
    ]
]

map_points.head()
# Out:
#   felling_period  felling_toponymy_source felling_toponymy_MTN25 province  \
# 0      1748-1749                   Benahú      Dehesa de Benahú     Cádiz
# 1      1748-1749                    Jarda    Dehesa de la Jarda     Cádiz
# 2      1748-1749  Barranco de la Fantasma           La Fantasma     Cádiz
# 3      1748-1749              La Jardilla           La Jardilla     Cádiz
# 4      1748-1749       Garganta de Millán                 Millán    Cádiz
#
#            municipality landownership        landowner_name tree_species  \
# 0  Jerez de la Frontera       comunal  Jerez de la Frontera     gall oak
# 1  Jerez de la Frontera     undefined             undefined     gall oak
# 2  Jerez de la Frontera     undefined             undefined     gall oak
# 3  Jerez de la Frontera       comunal  Jerez de la Frontera     gall oak
# 4  Jerez de la Frontera     undefined             undefined     gall oak
#
#    tree_quantity   latitude  longitude
# 0          622.0  36.576893  -5.509202
# 1          230.0  36.602238  -5.601913
# 2          240.0  36.609978  -5.464804
# 3         1457.0  36.621789  -5.518366
# 4          250.0  36.616171  -5.474945

# %% [markdown]
# ## 12. Summary tables for charts and maps

# %%
chart_periods = (
    df.groupby('felling_period')['tree_quantity']
    .sum()
    .reset_index()
    .sort_values(by='tree_quantity', ascending=False)
)

chart_periods.head()
# Out:
#   felling_period  tree_quantity
# 4      1749-1750        19093.1
# 0      1748-1749        18006.0
# 6           1750         8122.0
# 2      1748-1751         6943.0
# 1      1748-1750         4641.0

# %%
chart_provinces = (
    df.groupby('province')['tree_quantity']
    .sum()
    .reset_index()
    .sort_values(by='tree_quantity', ascending=False)
)

chart_provinces.head()
# Out:
#   province  tree_quantity
# 0    Cádiz        32920.1
# 2   Málaga        11888.0
# 3  Sevilla        11056.0
# 1   Huelva        10401.0

# %%
chart_municipalities = (
    df.groupby('municipality')['tree_quantity']
    .sum()
    .reset_index()
    .sort_values(by='tree_quantity', ascending=False)
)

chart_municipalities.head()
# Out:
#              municipality  tree_quantity
# 20  Cortes de la Frontera         7599.0
# 36  Jimena de la Frontera         7545.0
# 35   Jerez de la Frontera         6467.1
# 2        Alcalá del Valle         5238.0
# 48                  Ronda         4289.0

# %%
chart_species = (
    df.groupby('tree_species')['tree_quantity']
    .sum()
    .reset_index()
    .sort_values(by='tree_quantity', ascending=False)
)

chart_species.head()
# Out:
#         tree_species  tree_quantity
# 5                oak        18108.0
# 3           holm oak        15990.0
# 1           gall oak        13233.1
# 9  undefined species         6055.0
# 8               pine         5358.0

# %%
chart_landownership = (
    df.groupby('landownership')['tree_quantity']
    .sum()
    .reset_index()
    .sort_values(by='tree_quantity', ascending=False)
)

chart_landownership.head()
# Out:
#    landownership  tree_quantity
# 1        comunal        28848.1
# 5   noble estate        16106.0
# 11     undefined         7761.0
# 7        private         7726.0
# 3   ecclesiastic         2229.0

# %%
chart_landowners = (
    df.groupby('landowner_name')['tree_quantity']
    .sum()
    .reset_index()
    .sort_values(by='tree_quantity', ascending=False)
)

chart_landowners.head()
# Out:
#             landowner_name  tree_quantity
# 245              undefined         8016.0
# 120   Jerez de la Frontera         5509.1
# 121  Jimena de la Frontera         4698.0
# 224                  Ronda         4289.0
# 66          Duque de Arcos         3682.0

# %%
map_provinces = (
    df.groupby('province')['tree_quantity']
    .sum()
    .reset_index()
    .sort_values(by='tree_quantity', ascending=False)
)

map_provinces.head()
# Out:
#   province  tree_quantity
# 0    Cádiz        32920.1
# 2   Málaga        11888.0
# 3  Sevilla        11056.0
# 1   Huelva        10401.0

# %%
map_municipalities = (
    df.groupby('municipality')['tree_quantity']
    .sum()
    .reset_index()
    .sort_values(by='tree_quantity', ascending=False)
)

map_municipalities.head()
# Out:
#              municipality  tree_quantity
# 20  Cortes de la Frontera         7599.0
# 36  Jimena de la Frontera         7545.0
# 35   Jerez de la Frontera         6467.1
# 2        Alcalá del Valle         5238.0
# 48                  Ronda         4289.0

# %%
map_points.head()
# Out:
#   felling_period  felling_toponymy_source felling_toponymy_MTN25 province  \
# 0      1748-1749                   Benahú      Dehesa de Benahú     Cádiz
# 1      1748-1749                    Jarda    Dehesa de la Jarda     Cádiz
# 2      1748-1749  Barranco de la Fantasma           La Fantasma     Cádiz
# 3      1748-1749              La Jardilla           La Jardilla     Cádiz
# 4      1748-1749       Garganta de Millán                 Millán    Cádiz
#
#            municipality landownership        landowner_name tree_species  \
# 0  Jerez de la Frontera       comunal  Jerez de la Frontera     gall oak
# 1  Jerez de la Frontera     undefined             undefined     gall oak
# 2  Jerez de la Frontera     undefined             undefined     gall oak
# 3  Jerez de la Frontera       comunal  Jerez de la Frontera     gall oak
# 4  Jerez de la Frontera     undefined             undefined     gall oak
#
#    tree_quantity   latitude  longitude
# 0          622.0  36.576893  -5.509202
# 1          230.0  36.602238  -5.601913
# 2          240.0  36.609978  -5.464804
# 3         1457.0  36.621789  -5.518366
# 4          250.0  36.616171  -5.474945

# %% [markdown]
# ## 13. Main findings for the Streamlit app

# %%
df.groupby('province')['tree_quantity'] \
    .sum() \
    .sort_values(ascending=False)
# Out:
# province
# Cádiz      32920.1
# Málaga     11888.0
# Sevilla    11056.0
# Huelva     10401.0
# Name: tree_quantity, dtype: float64

# %%
df.groupby('municipality')['tree_quantity'] \
    .sum() \
    .sort_values(ascending=False) \
    .head(15)
# Out:
# municipality
# Cortes de la Frontera         7599.0
# Jimena de la Frontera         7545.0
# Jerez de la Frontera          6467.1
# Alcalá del Valle              5238.0
# Ronda                         4289.0
# Grazalema                     3863.0
# Ubrique                       3336.0
# Castellar de la Frontera      2068.0
# Benacazón                     1627.0
# Alcalá de los Gazules         1573.0
# El Castillo de las Guardas    1539.0
# Huévar                        1439.0
# Hinojos                       1363.0
# Sevilla                       1193.0
# Zufre                         1188.0
# Name: tree_quantity, dtype: float64

# %%
df.groupby('tree_species')['tree_quantity'] \
    .sum() \
    .sort_values(ascending=False)
# Out:
# tree_species
# oak                   18108.0
# holm oak              15990.0
# gall oak              13233.1
# undefined species      6055.0
# pine                   5358.0
# gall oak, cork oak     4392.0
# holm oak, gall oak     2775.0
# cork oak                311.0
# olive                    43.0
# oak, gall oak             0.0
# Name: tree_quantity, dtype: float64

# %%
df.groupby('landownership')['tree_quantity'] \
    .sum() \
    .sort_values(ascending=False)
# Out:
# landownership
# comunal                       28848.1
# noble estate                  16106.0
# undefined                      7761.0
# private                        7726.0
# ecclesiastic                   2229.0
# fallow land                    2193.0
# assistance institution         1001.0
# private, ecclesiastic           252.0
# noble estate, ecclesiastic       83.0
# private, comunal                 31.0
# comunal, ecclesiastic            29.0
# private, noble estate             6.0
# Name: tree_quantity, dtype: float64

# %%
df.groupby('landowner_name')['tree_quantity'] \
    .sum() \
    .sort_values(ascending=False) \
    .head(20)
# Out:
# landowner_name
# undefined                        8016.0
# Jerez de la Frontera             5509.1
# Jimena de la Frontera            4698.0
# Ronda                            4289.0
# Duque de Arcos                   3682.0
# Marqués de Benamejí              3593.0
# Duque de Medina Sidonia          3570.0
# Ubrique                          3150.0
# Pedro Manuel Motezuma            2986.0
# Cortes de la Frontera            2460.0
# Alcalá del Valle                 1645.0
# El Castillo de las Guardas       1299.0
# Duque de Santo Esteban           1113.0
# Zufre                             959.0
# Castellar de la Frontera          955.0
# Santa Olalla del Cala             851.0
# Conde de Torrejón                 675.0
# Ignacio de Castañeda              670.0
# Iglesia Patriarcal de Sevilla     668.0
# Misericordia de Sevilla           616.0
# Name: tree_quantity, dtype: float64

# %%
df.groupby('felling_period')['tree_quantity'] \
    .sum() \
    .sort_values(ascending=False)
# Out:
# felling_period
# 1749-1750    19093.1
# 1748-1749    18006.0
# 1750          8122.0
# 1748-1751     6943.0
# 1748-1750     4641.0
# 1749-1751     4284.0
# 1751          3447.0
# 1749          1183.0
# 1750-1751      546.0
# Name: tree_quantity, dtype: float64

# %%
top_province = df.groupby('province')['tree_quantity'].sum().sort_values(ascending=False).head(1)
top_municipality = df.groupby('municipality')['tree_quantity'].sum().sort_values(ascending=False).head(1)
top_species = df.groupby('tree_species')['tree_quantity'].sum().sort_values(ascending=False).head(3)
top_landownership = df.groupby('landownership')['tree_quantity'].sum().sort_values(ascending=False).head(3)
top_landowners = df.groupby('landowner_name')['tree_quantity'].sum().sort_values(ascending=False).head(5)
top_period = df.groupby('felling_period')['tree_quantity'].sum().sort_values(ascending=False).head(3)

print("Top province")
print(top_province)
print()

print("Top municipality")
print(top_municipality)
print()

print("Top species")
print(top_species)
print()

print("Top landownership types")
print(top_landownership)
print()

print("Top landowners")
print(top_landowners)
print()

print("Top periods")
print(top_period)
# Out:
# Top province
# province
# Cádiz    32920.1
# Name: tree_quantity, dtype: float64
#
# Top municipality
# municipality
# Cortes de la Frontera    7599.0
# Name: tree_quantity, dtype: float64
#
# Top species
# tree_species
# oak         18108.0
# holm oak    15990.0
# gall oak    13233.1
# Name: tree_quantity, dtype: float64
#
# Top landownership types
# landownership
# comunal         28848.1
# noble estate    16106.0
# undefined        7761.0
# Name: tree_quantity, dtype: float64
#
# Top landowners
# landowner_name
# undefined                8016.0
# Jerez de la Frontera     5509.1
# Jimena de la Frontera    4698.0
# Ronda                    4289.0
# Duque de Arcos           3682.0
# Name: tree_quantity, dtype: float64
#
# Top periods
# felling_period
# 1749-1750    19093.1
# 1748-1749    18006.0
# 1750          8122.0
# Name: tree_quantity, dtype: float64

# %% [markdown]
# ## 14. Charts

# %% [markdown]
# Provinces by total tree quantity

# %%
province_summary = (
    df.groupby('province', as_index=False)['tree_quantity']
    .sum()
    .sort_values(by='tree_quantity', ascending=False)
)

plt.figure(figsize=(10,10))

plt.pie(
    province_summary['tree_quantity'],
    labels=province_summary['province'],
    autopct='%1.1f%%',
    startangle=90
)

plt.title('Total tree quantities by province')

plt.show()

# %% [markdown]
# Top 15 municipalities by total tree quantity

# %%
municipality_summary = (
    df.groupby('municipality', as_index=False)['tree_quantity']
    .sum()
    .sort_values(by='tree_quantity', ascending=False)
    .head(15)
)

plt.figure(figsize=(12,6))
plt.bar(municipality_summary['municipality'], municipality_summary['tree_quantity'])
plt.title('Top 15 municipalities by tree quantity')
plt.xlabel('Municipality')
plt.ylabel('Tree quantity')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Tree species distribution

# %%
species_summary = (
    df.groupby('tree_species', as_index=False)['tree_quantity']
    .sum()
    .sort_values(by='tree_quantity', ascending=False)
)

plt.figure(figsize=(10,6))
plt.bar(species_summary['tree_species'], species_summary['tree_quantity'])
plt.title('Tree quantities by species')
plt.xlabel('Species')
plt.ylabel('Tree quantity')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Landownership distribution

# %%
ownership_summary = (
    df.groupby('landownership', as_index=False)['tree_quantity']
    .sum()
    .sort_values(by='tree_quantity', ascending=False)
)

plt.figure(figsize=(10,6))
plt.bar(ownership_summary['landownership'], ownership_summary['tree_quantity'])
plt.title('Tree quantities by landownership type')
plt.xlabel('Landownership')
plt.ylabel('Tree quantity')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Top landowners

# %%
landowner_summary = (
    df.groupby('landowner_name', as_index=False)['tree_quantity']
    .sum()
    .sort_values(by='tree_quantity', ascending=False)
    .head(15)
)

plt.figure(figsize=(12,6))
plt.bar(landowner_summary['landowner_name'], landowner_summary['tree_quantity'])
plt.title('Top 15 landowners by tree quantity')
plt.xlabel('Landowner')
plt.ylabel('Tree quantity')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Histogram of tree quantities

# %%
plt.figure(figsize=(10,6))
plt.hist(df['tree_quantity'].dropna(), bins=20)
plt.title('Distribution of tree quantities')
plt.xlabel('Tree quantity')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Records by year

# %%
period_summary = (
    df[['felling_period', 'tree_quantity']]
    .dropna()
    .copy()
)

# extrai o primeiro ano que aparece no texto do período
period_summary['period_start_year'] = (
    period_summary['felling_period']
    .astype(str)
    .str.extract(r'(\d{4})')[0]
    .astype(float)
)

# remove linhas onde não conseguiu encontrar ano
period_summary = period_summary.dropna(subset=['period_start_year']).copy()

# soma quantidades por período
period_summary = (
    period_summary
    .groupby(['felling_period', 'period_start_year'], as_index=False)['tree_quantity']
    .sum()
    .sort_values(by='period_start_year', ascending=True)
)

plt.figure(figsize=(12, 6))
plt.bar(period_summary['felling_period'], period_summary['tree_quantity'])
plt.title('Tree quantities by felling period')
plt.xlabel('Felling period')
plt.ylabel('Tree quantity')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Final analytical summary
#
# - Cádiz is by far the province with the highest total quantity of recorded felled trees, followed by Málaga, Sevilla and Huelva.
# - The municipalities with the largest quantities of recorded felled trees are Cortes de la Frontera, Jimena de la Frontera, Jerez de la Frontera and Alcalá del Valle.
# - Tree felling activity is strongly concentrated in a relatively small number of municipalities and specific places.
# - Oak, holm oak and gall oak are the dominant tree species in the dataset and together account for the majority of recorded tree quantities.
# - Pine is also significant, although much less represented than the main oak-related species.
# - Comunal landownership is the most important form of land control represented in the dataset, followed by noble estates, private land and ecclesiastical land.
# - A relatively small number of landowners account for a very large proportion of the total quantity of recorded felled trees.
# - Among the most important landowners are Jerez de la Frontera, Jimena de la Frontera, the Duque de Arcos, the Marqués de Benamejí and the Duque de Medina Sidonia.
# - The periods 1749–1750 and 1748–1749 are the most productive phases represented in the dataset.
# - A substantial proportion of the records includes valid coordinates, making it possible to create point maps of felling locations and combine them with polygon maps of provinces and municipalities.
